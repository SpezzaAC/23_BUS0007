# %% [markdown]
# # Model Training

# %% [markdown]
# ### scikit - learn
#
# https://scikit-learn.org/stable/
#
# scikitlearn (sklearn) provides simple and efficient tools for predictive data analysis. It is built on NumPy, SciPy, and matplotlib.

# %% [markdown]
# First thing, Import all the libraries

# %% [markdown]
# ## Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', 50)

# %%
# import the final data set
df = pd.read_csv('final.csv')
print(df.shape)
df.head()
# Out:
# (1863, 12)
#     price  property_tax  insurance  beds  baths  sqft  lot_size  basement  \
# 0  295850           234         81     1      1   584         0       0.0
# 1  216500           169         51     1      1   612         0       1.0
# 2  279900           216         74     1      1   615         0       0.0
# 3  379900           265         92     1      1   618     33541       0.0
# 4  340000            88         30     1      1   634         0       0.0
#
#   property_type  popular  recession  property_age
# 0         Condo        0          1             0
# 1         Condo        0          0            41
# 2         Condo        0          1            49
# 3         Condo        0          0             5
# 4         Condo        0          0            10

# %% [markdown]
# ## One hot encoding
# Converting categorical variables to flag variables

# %%
df = pd.get_dummies(df, columns = ['property_type']) #drop_first

# %%
df.head()
# Out:
#     price  property_tax  insurance  beds  baths  sqft  lot_size  basement  \
# 0  295850           234         81     1      1   584         0       0.0
# 1  216500           169         51     1      1   612         0       1.0
# 2  279900           216         74     1      1   615         0       0.0
# 3  379900           265         92     1      1   618     33541       0.0
# 4  340000            88         30     1      1   634         0       0.0
#
#    popular  recession  property_age  property_type_Bunglow  \
# 0        0          1             0                      0
# 1        0          0            41                      0
# 2        0          1            49                      0
# 3        0          0             5                      0
# 4        0          0            10                      0
#
#    property_type_Condo
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
df.describe()
# Out:
#                price  property_tax    insurance         beds        baths  \
# count    1863.000000   1863.000000  1863.000000  1863.000000  1863.000000
# mean   423010.393451    461.369834   138.816425     3.409018     2.564144
# std    151764.257544    222.484352    70.250523     1.065101     0.928741
# min    200000.000000     88.000000    30.000000     1.000000     1.000000
# 25%    300000.000000    319.000000    94.000000     3.000000     2.000000
# 50%    392000.000000    423.000000   124.000000     3.000000     3.000000
# 75%    525000.000000    564.000000   168.000000     4.000000     3.000000
# max    800000.000000   4508.000000  1374.000000     5.000000     6.000000
#
#               sqft       lot_size     basement      popular    recession  \
# count  1863.000000    1863.000000  1863.000000  1863.000000  1863.000000
# mean   2299.173913   12522.044552     0.879227     0.095545     0.263553
# std    1298.029915   35040.992371     0.325951     0.294045     0.440678
# min     500.000000       0.000000     0.000000     0.000000     0.000000
# 25%    1342.500000    1540.000000     1.000000     0.000000     0.000000
# 50%    1900.000000    5846.000000     1.000000     0.000000     0.000000
# 75%    2951.000000   11325.000000     1.000000     0.000000     1.000000
# max    7842.000000  436471.000000     1.000000     1.000000     1.000000
#
#        property_age  property_type_Bunglow  property_type_Condo
# count   1863.000000            1863.000000          1863.000000
# mean      24.397209               0.569512             0.430488
# std       21.087996               0.495278             0.495278
# min        0.000000               0.000000             0.000000
# 25%        6.000000               0.000000             0.000000
# 50%       21.000000               1.000000             0.000000
# 75%       38.000000               1.000000             1.000000
# max      114.000000               1.000000             1.000000

# %% [markdown]
# **Before you begin modeling, you should split the data in train and test subsets.**
# * Training sets are used to fit and tune your models.
# * Test sets are put aside as "unseen" data to evaluate your models.
# * The `train_test_split()` function splits data into randomized subsets.

# %%
# seperate the target variable
y = df.price

# seperate the features
x = df.drop('price', axis=1)

# df.iloc[:,1:3]

# %%
# import module for train-test split
from sklearn.model_selection import train_test_split

# Split the dataset
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.20, random_state=1234)

# %%
# check records in each split
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((1490, 12), (373, 12), (1490,), (373,))

# %%
# import the model
from sklearn.linear_model import LinearRegression

# train the model
#del model
lrmodel = LinearRegression().fit(xtrain,ytrain)

# %%
# make prediction on train set
ytrain_pred = lrmodel.predict(xtrain)

# %%
# import mean absolute error metric
from sklearn.metrics import mean_absolute_error

# evaluate the model
train_mae = mean_absolute_error(ytrain_pred, ytrain)
train_mae
# Out:
# 97227.57775824107

# %%
# make predictions using the x_test values
ytest_pred = lrmodel.predict(xtest)

# %%
# evaluate the model
test_mae = mean_absolute_error(ytest_pred, ytest)
test_mae
# Out:
# 86427.77989910396

# %% [markdown]
# ## Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor().fit(xtrain,ytrain)

# %%
# plotting tree
from sklearn import tree
fig = plt.figure(figsize=(25,20))
tree.plot_tree(dt, filled=True)
plt.show()

# %%
# Prune the tree using hyperparameters
dt = DecisionTreeRegressor(max_depth=3, min_samples_split=30).fit(xtrain,ytrain)
from sklearn import tree
tree.plot_tree(dt, filled=True);

# %%
ytrain_pred = dt.predict(xtrain)
dt_mae = mean_absolute_error(ytrain_pred, ytrain)
print('Train error is',dt_mae)
# Out:
# Train error is 82393.86849553732

# %%
# make predictions using the x_test values
ytest_pred = dt.predict(xtest)

# evaluate the model
test_mae = mean_absolute_error(ytest_pred, ytest)
test_mae
# Out:
# 74837.37947455472

# %% [markdown]
# ## Random Forest Model

# %%
# import Random Forest model from scikit learn
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=200,criterion='absolute_error').fit(xtrain,ytrain)
ytrain_pred = rf.predict(xtrain)
rftrain_mae = mean_absolute_error(ytrain_pred, ytrain)
print('Train error RF model is',rftrain_mae)
# Out:
# Train error RF model is 31234.106125838924

# %%
# make predictions on the x_test values
ytest_pred = rf.predict(xtest)

# evaluate the model
rftest_mae = mean_absolute_error(ytest_pred, ytest)
rftest_mae
# Out:
# 71502.14254691688

# %% [markdown]
# #### From the observations above, answers the following questions:

# %% [markdown]
# Q1. Which model gave the lowest error? - 1 point

# %% [markdown]
# Ans: The Random Forest Model provided the lowest error, prior to the drop. After the drop, the Decision tree had the lowest error.

# %% [markdown]
# Q2. Why was linear regression not a suitable choice for this data? - 1 point

# %% [markdown]
# Ans: Linear regression is sensitive to outliers.

# %% [markdown]
# Q3. Which are the top 5 important features in this dataset? - 1 point

# %% [markdown]
# Ans: The top 5 important features within this dataset are property_tax, insurance, beds, baths, and spft.

# %% [markdown]
# ## Saving the Model

# %% [markdown]
# ## Pickle:
#
# * The pickle module implements a fundamental, but powerful algorithm for serializing and de-serializing a Python object structure.
#
# * The saving of data is called Serialization, while restoring the data is called Deserialization.
#
# **Pickle** model provides the following functions:
# * **`pickle.dump`** to serialize an object hierarchy, you simply use `dump()`.
# * **`pickle.load`** to deserialize a data stream, you call the `loads()` function.

# %%
# import pickle to save model
import pickle
 
# Save the trained model on the drive 
pickle.dump(lrmodel, open('RE_Model','wb'))

# %%
# Load the pickled model
RE_Model = pickle.load(open('RE_Model','rb'))

# %%
np.array(xtrain.loc[22])
# Out:
# array([139.,  42.,   1.,   1., 703.,   0.,   1.,   0.,   0.,  13.,   0.,
#          1.])

# %%
ytrain[22]
# Out:
# 240000

# %%
df
# Out:
#        price  property_tax  insurance  beds  baths  sqft  lot_size  basement  \
# 0     295850           234         81     1      1   584         0       0.0
# 1     216500           169         51     1      1   612         0       1.0
# 2     279900           216         74     1      1   615         0       0.0
# 3     379900           265         92     1      1   618     33541       0.0
# 4     340000            88         30     1      1   634         0       0.0
# ...      ...           ...        ...   ...    ...   ...       ...       ...
# 1858  760000           881        249     5      5  7842    436035       1.0
# 1859  690000          1553        473     5      6  6501     23086       1.0
# 1860  600000           942        287     5      6  7064    217800       1.0
# 1861  759900           803        245     5      6  7500      8886       1.0
# 1862  735000          1459        444     5      6  7515     10497       1.0
#
#       popular  recession  property_age  property_type_Bunglow  \
# 0           0          1             0                      0
# 1           0          0            41                      0
# 2           0          1            49                      0
# 3           0          0             5                      0
# 4           0          0            10                      0
# ...       ...        ...           ...                    ...
# 1858        0          0             5                      1
# 1859        0          0            59                      1
# 1860        0          0             4                      1
# 1861        0          0             3                      1
# 1862        0          0            57                      1
#
#       property_type_Condo
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 1858                    0
# 1859                    0
# 1860                    0
# 1861                    0
# 1862                    0
#
# [1863 rows x 13 columns]

# %%
# Use the loaded pickled model to make predictions
RE_Model.predict([[139,  42,   1,   1, 703,   0,   1,  0,   0,   6,   1,  0]])
# Out:
# C:\Users\Spencer\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([277715.70738287])
